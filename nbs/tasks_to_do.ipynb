# %% [markdown]
# # To Do Next
#
# 1. Make new CV from the previous dataclass in 03_documents. Store it in 04_documents.
# 2. Modify code map and dataclass in 01_documents and import from 01 to 04 add save/load functionalities
# 3. HTML and CSS in different folders
# 4. Create folders for CV, LOM and Job Descriptions
# 5. Create Dictionary for CV, LOM and Job Description(markdowns)
# 6. Create Markdown with Job-Description-LOM-CV for 1 dictionary entry.
# 7. Find how we can use the data.
