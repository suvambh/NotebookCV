# %%
#| default_exp example

# %%
#| hide
from nbdev.showdoc import *

# %%
from NotebookCV.document import *

cv = CVDocument(
    language="fr",

    name="Suvam Bhattacharya",
    title="Data Scientist | Machine Learning & AI Systems",
    location="France",
    summary="""Data scientist avec une solide expertise en modélisation statistique et en machine learning, combinée à une expérience en ingénierie des données et environnements cloud. Maîtrise de Python et SQL pour le développement de modèles prédictifs et l’extraction d’insights à partir de données complexes. Expérience dans la conception de pipelines de données robustes et scalables, ainsi que dans le déploiement de modèles en production via des outils CI/CD et des technologies cloud. Intéressé par le développement de solutions d’intelligence artificielle appliquées (NLP, extraction d’informations) et leur industrialisation.""",

    contact=Contact(
        email="fmahuyac@gmail.com",
        phone="+33663299291",
        linkedin="https://www.linkedin.com/in/suvam-bhattacharya-716271102/",
        github="https://github.com/suvambh",
    ),

    skills=[
        SkillCategory("Langages", ["Python", "SQL", "Bash"]),
        SkillCategory("Machine Learning & AI", [
            "scikit-learn", "PyTorch",
            "NLP", "Modèles de classification",
            "Détection d’anomalies"
        ]),
        SkillCategory("MLOps & Data", [
            "CI/CD", "GitLab CI", "AWS",
            "Pipelines de données", "Data Warehousing"
        ]),
        SkillCategory("Data Engineering", [
            "ETL",
            "Modélisation des données",
            "Qualité des données"
        ]),
    ],

    experience=[
        Experience(
            role="Ingénieur Data / Cloud",
            company="Eolen AS+",
            location="Bruyères-le-Châtel",
            start_date="2024",
            end_date="2024",
            bullets=[
                "Technologies: AWS, Terraform, EKS, Slurm, GitLab CI, Bash, Python",
                "Mise en place de pipelines CI/CD pour industrialiser le déploiement d’environnements de traitement de données distribués.",
                "Conception de workflows reproductibles pour le traitement et l’exploitation de données à grande échelle.",
                "Optimisation des performances des traitements de données (calcul et stockage) dans des environnements cloud.",
                "Mise en place d’infrastructures robustes permettant le déploiement et l’exécution de pipelines data et de modèles.",
                "Contribution à des projets data intensifs dans un contexte scientifique et industriel."
            ],
        ),

        Experience(
            role="Data Scientist",
            company="Freelance",
            location="",
            start_date="2023",
            end_date="2023",
            bullets=[
                "Technologies: Python, SQL, AWS, Machine Learning, Power BI",
                "Développement de modèles de prévision SARIMA pour anticiper l’évolution des ventes et soutenir la prise de décision.",
                "Évaluation et amélioration des performances des modèles à l’aide de métriques statistiques adaptées.",
                "Exploration et expérimentation de différentes approches de modélisation pour sélectionner les solutions les plus performantes.",
                "Conception et mise en place de pipelines de données et d’un data warehouse (AWS, Talend) pour structurer et fiabiliser les données.",
                "Analyse de données commerciales et production de tableaux de bord (Power BI, Excel) pour identifier des tendances et générer des insights exploitables.",
                "Collaboration avec les parties prenantes pour traduire les besoins métier en solutions analytiques."
            ],
        ),

        Experience(
            role="Doctorant en Physique",
            company="LPS",
            location="Orsay",
            start_date="2018",
            end_date="2022",
            bullets=[
                "Technologies: Python, NumPy, scikit-learn, PyTorch, matplotlib, Jupyter",
                "Analyse statistique de données expérimentales complexes pour identifier des patterns, anomalies et signaux faibles.",
                "Développement et application de modèles de machine learning pour la détection de motifs dans des données bruitées.",
                "Modélisation de systèmes complexes et validation des modèles à l’aide de méthodes statistiques rigoureuses.",
                "Conception d’outils d’analyse et de visualisation pour faciliter l’interprétation et la communication des résultats.",
                "Thèse: https://theses.hal.science/tel-03577251/"
            ]
        ),

        Experience(
            role="Enseignant en Informatique",
            company="I.U.T.",
            location="Orsay",
            start_date="2019",
            end_date="2021",
            bullets=[
                "Technologies: POO, algorithmes avancés",
                "Enseignement POO et structures algorithmiques.",
                "Encadrement de projets data et vulgarisation de concepts techniques auprès d’un public étudiant.",
            ],
        ),
    ],

    education=[
        Education(
            degree="Diplôme d’ingénieur polytechnicien",
            institution="École Polytechnique",
            location="Palaiseau",
            start_date="2014",
            end_date="2018",
            details=[
                "Physique : physique numérique, physique statistique",
                "Mathématiques : probabilités, statistiques, optimisation",
                "Informatique : Python, algorithmique, logique"
            ]
        )
    ],

    certifications=[
        Certification(
            name="Data Management",
            issuer="Datascientest, Paris",
            date="2023",
            link="",
        ),
        Certification(
            name="AWS Certified Solutions Architect – Associate",
            issuer="AWS",
            date="2024",
            link="",
        ),
        Certification(
            name="Applied Machine Learning in Python",
            issuer="University of Michigan",
            date="",
            link="",
        ),
        Certification(
            name="Introduction to Data Science in Python",
            issuer="University of Michigan",
            date="",
            link="",
        ),
        Certification(
            name="Machine Learning in Production",
            issuer="DeepLearning.AI",
            date="",
            link="",
        ),
    ],
)

# %%
from NotebookCV.render import save_pdf
from pathlib import Path
company="Credit_Agricole_Assurance"
role="Data_Scientist"
save_pdf(cv, company, role)
# Out:
# Path('../outputs/cv/Credit_Agricole_Assurance_Data_Scientist_cv_suvam_bhattacharya.pdf')

# %%
import nbdev; nbdev.nbdev_export()
