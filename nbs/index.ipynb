# %%
#| hide
from NotebookCV.core import *

# %% [markdown]
# # NotebookCV
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install NotebookCV in Development mode

# %% [markdown]
# ```sh
# # make sure NotebookCV package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to NotebookCV
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/suvambh/NotebookCV.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c suvambh NotebookCV
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install NotebookCV
# ```
#
#
# [repo]: https://github.com/suvambh/NotebookCV
# [docs]: https://suvambh.github.io/NotebookCV/
# [pypi]: https://pypi.org/project/NotebookCV/
# [conda]: https://anaconda.org/suvambh/NotebookCV

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/suvambh/NotebookCV
# [docs]: https://suvambh.github.io/NotebookCV/
# [pypi]: https://pypi.org/project/NotebookCV/
# [conda]: https://anaconda.org/suvambh/NotebookCV

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
